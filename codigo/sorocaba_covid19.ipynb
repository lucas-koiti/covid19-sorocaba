# %% [markdown]
# # Graficos de casos Confirmados e Óbitos na cidade de Sorocaba

# %%
import pandas as pd
import plotly.express as px

dataf = pd.read_csv('../dados/planilha_csv/dados.csv')

# %%
fig = px.line(dataf, x = 'Dia', y = 'Confirmados', title='Covid-19 Casos Confirmados em Sorocaba')


fig.show()

# %%
fig = px.line(dataf, x = 'Dia', y = 'Obitos', title='Covid-19 Óbitos em Sorocaba')


fig.show()

# %% [markdown]
# ## Taxa de Letalidade
# Análise das mudanças recentes na taxa de letalidade.

# %%
c = dataf["Confirmados"].max()
o = dataf["Obitos"].max()

taxa_mortalidade = (o/c)*100

print(taxa_mortalidade)
# Out:
# 2.153623269161118

# %%
interval = dataf[(dataf["taxa_letalidade"] < 3) & (dataf["taxa_letalidade"] > 2.2)]

fig = px.line(interval, x = 'Dia', y = 'taxa_letalidade', title='Covid-19 Taxa de Letalidade ao longo do tempo em Sorocaba')


fig.show()
